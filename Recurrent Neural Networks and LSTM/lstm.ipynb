# %% [markdown]
# # **LONG SHORT-TERM MEMORY**

# %% [markdown]
# ## **OS PROBLEMAS DO GRADIENTE**

# %% [markdown]
# Dentro desses materiais, descrevi diversas formas de tentar segurar a explosão ou o desaparecimento do gradiente.
